# %%
import numpy as np
np.array([1, 2, 3, 4, 5])
array
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\silve\OneDrive\Desktop\curso-analisis\hola.py in <module>
#       1 import numpy as np
#       2 np.array([1, 2, 3, 4, 5])
# ----> 3 array
#
# NameError: name 'array' is not defined

# %%
import numpy as np
array = np.array([1, 2, 3, 4, 5])
array
# Out:
# array([1, 2, 3, 4, 5])

# %%
array
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\silve\OneDrive\Desktop\curso-analisis\hola.py in <module>
# ----> 1 array
#
# NameError: name 'array' is not defined

# %%
import numpy as np
array = np.array([1, 2, 3, 4, 5])

# %%
array
# Out:
# array([1, 2, 3, 4, 5])

# %% [markdown]
#  # Esto es un título
#  ## Esto es un subtítulo
#  Esto es un parágrafo con __negritas__ y _cursivas_.

# %%
import numpy as np
import pandas as pd

tabla = pd.DataFrame(
    np.random.randint(
        0, 100, size=(4, 3)
    ),
    columns=['Pepe', 'María', 'Juan']
)

tabla
# Out:
#    Pepe  María  Juan
# 0    12     46    40
# 1    34     29    95
# 2    28     49    47
# 3    57     68     4

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

tabla = pd.DataFrame(
    np.random.randint(
        0, 100, size=(4, 3)
    ),
    columns=['Pepe', 'María', 'Juan']
)

tabla.plot()
plt.show()
